# %%
from scripts.starss import StarssData

# %%
data = StarssData("starss22_metadata_dev")

# %%
data.generate_graphes("figures")

# %%
data.generate_item_files(300)
data.save_item_file("item_files")

# %%
data.generate_item_files(500)
data.save_item_file("item_files")

# %%
data.generate_item_files(1000)
data.save_item_file("item_files")
